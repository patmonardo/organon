# %% [markdown]
# # Being-for-self Notebook
#
# This notebook tracks methodological notes for Being-for-self workbooks.
# It is non-authoritative relative to workbook artifacts.

# %% [markdown]
# ## Source Set
#
# - `being-for-self.txt` (Part A)
# - `one-many.txt` (Part B)
# - `attraction.txt` (Part C)

# %% [markdown]
# ## Protocol
#
# 1. Obey labeled subtopics first.
# 2. Keep first pass bounded: marker + up to 3 entries.
# 3. Max 3 claims per entry with line evidence.
# 4. Defer numbered micro-analysis until whole-view pass.

# %% [markdown]
# ## Seed Focus
#
# - Stabilize Part A/B/C marker structure.
# - Keep transition links explicit across parts.
# - Defer heavy synthesis to IDEA/COMPILER whole-view pass.
