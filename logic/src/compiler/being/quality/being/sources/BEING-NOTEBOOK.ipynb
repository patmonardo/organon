# %% [markdown]
# # Being Notebook
#
# This notebook tracks methodological notes for the Being sphere workbooks.
# It is non-authoritative relative to workbook artifacts.

# %% [markdown]
# ## Source Set
#
# - `being.txt` (Part A)
# - `nothing.txt` (Part B)
# - `becoming.txt` (Part C)

# %% [markdown]
# ## Protocol
#
# 1. Lock spans first.
# 2. Add first-order fact claims with line evidence.
# 3. Add typed relations only after claim stability.
# 4. Validate cross-part transitions bidirectionally.

# %% [markdown]
# ## Today Focus
#
# - Workbook-first execution for `being/sources`.
# - Keep notebook as exploratory pressure-release.
# - Prioritize `TruthOf` modeling while preserving explicit transition coverage.
# - Defer speculative overlays unless source anchoring is complete.

# %% [markdown]
# ## Initial Modeling Prompt (Working)
#
# - How does `Nothing` function as truth of pure indeterminate `Being`?
# - How does `Becoming` function as truth of the relation between Being and Nothing?
# - Which claims are first-order textual, and which are second-order relation overlays?
