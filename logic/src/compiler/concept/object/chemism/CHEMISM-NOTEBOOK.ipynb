# %% [markdown]
# # CHEMISM NOTEBOOK
#
# Working notebook for block-level review before fine moment subdivision.

# %% [markdown]
# ## Scope
# - Source files: `object.txt`, `process.txt`, `chemism.txt`
# - Workbooks: `CHEMISM-PART-A-WORKBOOK.md`, `CHEMISM-PART-B-WORKBOOK.md`, `CHEMISM-PART-C-WORKBOOK.md`, `CHEMISM-IDEA-WORKBOOK.md`, `CHEMISM-COMPILER-WORKBOOK.md`
# - Method: block-first extraction for graph-in-execution planning.

# %% [markdown]
# ## ID convention lock
# - Entry IDs use hyphenated zero-padding by section block: `obj-chem-<part>-<section>-<nnn>`
# - Claim IDs append claim index: `...-c1`, `...-c2`
# - Keep this convention stable across workbook, notebook notes, and compiler maps.

# %% [markdown]
# ## Segmentation lock (current)
# - Part A (`object.txt`): study-first, no subspecies locked yet.
# - Part B (`process.txt`): numeric subentries `001|002|003` from labeled sections `1|2|3`.
# - Part C (`chemism.txt`): paragraph segmentation `001|002|003`.

# %% [markdown]
# ## Next review focus
# 1. Study `object.txt` to lock Part A block boundaries.
# 2. Refine Part B/C blocks into moments only after review.
# 3. Promote only reviewed, line-anchored relations into compiler operation maps.
