# %% [markdown]
# # OBJECT NOTEBOOK
#
# Working notebook for block-level review before fine moment subdivision.

# %% [markdown]
# ## Scope
# - Source files: `object.txt`, `process.txt`, `mechanism.txt`
# - Workbooks: `MECHANISM-PART-A-WORKBOOK.md`, `MECHANISM-PART-B-WORKBOOK.md`, `MECHANISM-PART-C-WORKBOOK.md`, `MECHANISM-IDEA-WORKBOOK.md`, `MECHANISM-COMPILER-WORKBOOK.md`
# - Method: block-first extraction for graph-in-execution planning.

# %% [markdown]
# ## ID convention lock
# - Entry IDs use hyphenated zero-padding by section block: `obj-mech-<part>-<section>-<nnn>`
# - Claim IDs append claim index: `...-c1`, `...-c2`
# - Examples: `obj-mech-b-a-001`, `obj-mech-c-b-003`, `obj-mech-b-tr-001`
# - Keep this convention stable across workbook, notebook notes, and compiler maps.

# %% [markdown]
# ## Block map (current)
# - Part A (`object.txt`): coarse blocks at numbered sections (`001-003`).
# - Part B (`process.txt`): `a` numeric (`a-001..003`), `b` paragraph (`b-001..003`), `c` paragraph (`c-001..003`), transition (`tr-001`).
# - Part C (`mechanism.txt`): `a` block (`a-001..006`), `b` paragraph (`b-001..003`), `c` block (`c-001..003`).

# %% [markdown]
# ## Next review focus
# 1. Decide where each block should be split into finer moments.
# 2. Mark high-value relations for execution-graph sequencing.
# 3. Promote only line-anchored, reviewed relations into compiler operation maps.
