# %% [markdown]
# # COMPILER NOTEBOOK: Membership / Consequencia Protocol (draft)
#
# Purpose: exploratory notebook to model the genetic move (membership -> consequencia). This keeps the main workbook unchanged and collects relations content for the compiler overlay.

# %% [markdown]
# ## Short summary
# - Membership protocol: a presupposed Monad (Concept being divided) yields a Dyad (Being / Nothing) as membership outcome.
# - Consequencia protocol: the Sphere of Essence instantiates the consequent/implicative development (A -> B -> sublation).
# - Genetic move: prior Dyad (a priori dichotomy) generates a new, posterior Dyad (ceasing/coming-to-be) while preserving the same absolute presupposition.
# - Hypothesis: a network/circle of locally-generated dyads all presuppose a single Absolute Concept (the Concept-being-divided).

# %% [markdown]
# ## Protocol primitives (draft KG keys)
# - `protocol_mode`: `membership` | `consequencia`
# - `presupposes_monad`: node ref to the presupposed Concept (e.g., `Becoming`),
# - `genetic_from`: edge from prior dyad -> generated dyad,
# - `dyad_elements`: pair listing the two moments (e.g., `[Being, Nothing]`),
# - `dyad_result`: posterior pair (e.g., `[Ceasing-to-be, Coming-to-be]`),
# - `proof_path`: anchor to workbook entries / claim ids that show the inference.
#
# Suggested relation types to add later in the workbook relations overlay: `presupposes_monad`, `genetic_from`, `protocol_mode`, `dyad_cycle_with`, `proof_path`.
# Keep these as second-order modeling relations (do not convert to first-order source claims).

# %% [markdown]
# ## Mapping suggestions to Part B workbook entries
# - Anchor `presupposes_monad` to `Becoming` (conceptually) and map `dyad_elements` -> entries `ess-ref-b-001` (Being-derived shine) and the Being-sphere entry set.
# - Anchor `genetic_from` edges from the Being-dyad (ess-ref-b-001 / related Part A entries) to the Essence-dyad (ess-ref-b-003 / ess-ref-b-004), showing how the prior dyad produces the posterior dyad.
# - Use `proof_path` to reference claim ids such as `ess-ref-b-001-c3` -> `ess-ref-b-002-c3` -> `ess-ref-b-003-c3` as the sequence evidencing the genetic inference.
#
# Note: do not edit the main workbook; instead keep relation-overlay drafts here and later port a vetted overlay into the `Relations` sections as a separate commit.

# %% [markdown]
# ## Next steps (proposed)
# 1. Review this draft with you and refine the KG keys and relation types.
# 2. Expand `proof_path` by listing exact claim ids and evidence spans for each inferred edge.
# 3. Produce a relations overlay file (YAML/MD) that can be imported into the workbook `Relations` sections without changing claims.
# 4. If desired, perform a batch rename to remove `-V2-` from workbook filenames (dry-run first to check references).

# %% [markdown]
# ## New synthesis notes (2026-02-20)
#
# - Working thesis: the dialectical method is a genetic method grounded in Kantian logical relations.
# - Objective Logic as higher dyad: Being and Essence form a pure a priori dichotomy, while still participating in triadic relation movement.
# - Membership protocol (disjunctive division): Concept-being-divided establishes initial definition through dyadic division.
# - Within Being: disjunction yields consequential development (e.g., transition dynamics such as coming-to-be / ceasing-to-be).
# - Within Essence: non-being is not mere absence but determinate disjunctive scope; consequentia appears with different logical range and nesting levels.
# - Inherence layer: prior and posterior dyads are treated as inhering in the presupposed conceptual unity.
# - Method claim (not first-order claim): analysis and synthesis are simultaneous in the sequence of the three relations.
# - Truth/knowledge hypothesis: triadic movement functions as a truth-knowledge bridge (Aristotelian dialectic framing used as interpretive scaffold only).
#
# ## Notebook discipline boundary
#
# - Keep these lines as second-order inferential notes in the notebook.
# - Do not inject these as first-order source claims into workbook entries.
# - Promote only vetted items into Relations overlays with explicit `proof_path` chains.
#
# ## Relation-overlay TODO (for compiler prep)
#
# - Add `protocol_mode` edges where transitions imply Membership vs Consequentia scope.
# - Add `presupposes_monad` for dyads traced to Concept-being-divided.
# - Add `inherence_of_dyad` to capture prior/posterior dyads inhering in conceptual unity.
# - Add `proof_path` sequences from claim IDs before relation export to compiler-facing logical operations.

# %% [markdown]
# ## Transcendental location + self-enclosure (new)
#
# - Fichte anchor: the Concept-being-divided can be modeled as `self_enclosure` (auto-positioning unity that generates its own inner difference).
# - Location thesis: Topics are not only terms; they are `trans_location` nodes in a logical topography.
# - Dyad placement: each dyad is a located subseries element, not an isolated pair.
# - Being and Essence as locations: these spheres are higher-order `trans_location` regions, each hosting internal dyadic series.
# - Presupposition hierarchy: Being-location and Essence-location both presuppose the Sphere of Concept as their enabling enclosure.
# - Root location claim (second-order): the Sphere of Concept is rooted in Absolute Concept as `root_location`.
# - Recognition framing: Pure a priori locations are moments of Absolute self-recognition (modeling hypothesis, notebook-only).
#
# ### Compiler-oriented relation keys (draft)
#
# - `trans_location_of(topic, sphere)`
# - `self_enclosed_by(location, concept_node)`
# - `subseries_member_of(dyad, sphere_series)`
# - `presupposes_root_location(location, root_location)`
# - `recognition_moment_of(location, absolute_concept)`
#
# ### Constraint reminder
#
# - Keep this block as second-order protocol semantics.
# - Promote to workbook `Relations` only after claim-anchored `proof_path` chains are specified.

# %% [markdown]
# ## Proof-path overlay preview (from draft artifact)
#
# Source artifact: `ESSENCE-RELATIONS-GENESIS.md`
#
# - `or1` Membership framing (Part A):
#   - proof path: `ess-ref-a-001-c3 -> ess-ref-a-002-c1 -> ess-ref-a-002-c2`
# - `or2` Consequentia turn (A -> B):
#   - proof path: `ess-ref-a-003-c1 -> ess-ref-a-003-c3 -> ess-ref-b-001-c1`
# - `or3` Consequentia development (Part B middle):
#   - proof path: `ess-ref-b-002-c3 -> ess-ref-b-003-c2 -> ess-ref-b-003-c3 -> ess-ref-b-004-c3`
# - `or4` Genetic dyad generation:
#   - proof path: `ess-ref-a-001-c3 -> ess-ref-a-003-c3 -> ess-ref-b-001-c3 -> ess-ref-b-003-c3`
# - `or5` Inherence modeling:
#   - proof path: `ess-ref-b-004-c2 -> ess-ref-b-004-c3 -> ess-ref-b-005-c3`
#
# Review gate:
# - Keep all entries as second-order overlay until each path is validated for minimal sufficiency and interpretive scope.

# %% [markdown]
# ## Dyad-wheel update (A+B -> C)
#
# - Part A + Part B are modeled as one appended dyad-segment in the wheel of dyads.
# - Part C is staged as the explicit inherence activation zone.
# - Being-Nothing-Becoming remains modeled as triadic protocol in immediacy scope.
# - In Essence, the same triadic protocol persists but with shifted scope: consequentia-dominant, then inherence intensifies toward Part C.
#
# Practical modeling rule:
# - Keep `or9` / `or10` in pending state until Part C claim anchors are attached.
# - Keep Being-side triadic claims pending until Being workbook anchors are imported.
