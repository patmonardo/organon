# %% [markdown]
# # Existence Notebook
#
# This notebook tracks methodological notes for Existence sphere workbooks.
# It is non-authoritative relative to workbook artifacts.

# %% [markdown]
# ## Source Normalization (7 -> 3)
#
# Artifact source split is normalized into three logical parts:
#
# - Part A (`EXISTENCE AS SUCH`): `existence.txt`
# - Part B (`FINITUDE`): `something-and-other.txt`, `constitution.txt`, `finitude.txt`
# - Part C (`INFINITY`): `infinity.txt`, `alternating-infinity.txt`, `affirmative-infinity.txt`

# %% [markdown]
# ## Human-Scale Protocol
#
# 1. Keep each entry readable in one sitting (no micro-fragmentation).
# 2. First pass cap: 1 marker + 1-3 numbered entries per part.
# 3. Max 3 claims per entry.
# 4. Add typed relations only after claim stability.
# 5. Preserve explicit transition links between parts.

# %% [markdown]
# ## TruthOf Emphasis (Working)
#
# - Transition coverage remains required.
# - But first-order extraction should foreground stable `TruthOf` anchors before higher-order inferential overlays.
# - In review, prefer conceptual clarity over maximal claim count.
